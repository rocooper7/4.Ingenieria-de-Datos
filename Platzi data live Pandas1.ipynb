# %% [markdown]
# ## Series

# %%
import pandas as pd

series_test = pd.Series([100, 200, 300])

series_test
# Out:
# 0    100
# 1    200
# 2    300
# dtype: int64

# %%
series_test2 = pd.Series({1999: 48, 
                          2000: 65, 
                          2001: 89})

series_test2
# Out:
# 1999    48
# 2000    65
# 2001    89
# dtype: int64

# %% [markdown]
# ## DataFrames

# %%
frame_test = pd.DataFrame({1999: [74, 38, 39],
                           2000: [34, 32, 32],
                           2001: [23, 39, 23]})

frame_test
# Out:
#    1999  2000  2001
# 0    74    34    23
# 1    38    32    39
# 2    39    32    23

# %%
frame_test2 = pd.DataFrame([[74, 38, 39],
                           [34, 32, 32],
                           [23, 39, 23]], columns=[1999, 2000, 2001])

frame_test2
# Out:
#    1999  2000  2001
# 0    74    38    39
# 1    34    32    32
# 2    23    39    23

# %% [markdown]
# ## Read data

# %%
pd.options.display.max_rows = 10

el_universal = pd.read_csv('C:\Python\eluniversal_2020_02_24_articles.csv',encoding='utf-8')

el_universal
# Out:
#                                                   body  \
# 0    \r\nEnvuelto en las crisis de feminicidio, seg...
# 1    \r\nLa inflación nacional alcanzó el nivel más...
# 2    \r\nLas "decisiones increíblemente difíciles" ...
# 3    \r\nRodolfo Cota, portero de León, podría ser ...
# 4    \r\nEn unas semanas, Radio Disney regresa en l...
# ..                                                 ...
# 148  \r\nSINALOA, MÉXICO. - Los laboratorios clande...
# 149  \r\n\r\n\r\n\r\n    googletag.cmd.push(functio...
# 150  \r\nConforme a los ajustes a la Ley Ambiental ...
# 151  \r\nEsta semana se reanuda la actividad de la ...
# 152  \r\n\r\nAnte la escasez de ingresos, la poblac...
#
#                                                  title  \
# 0       AMLO y Madero, entre la devoción y la obsesión
# 1    Inflación alcanza nivel más alto desde fines d...
# 2    China probablemente evitó cientos de miles de ...
# 3    Portero de León sería sancionado por protesta ...
# 4    Radio Disney regresa; por el 92.1 FM de Grupo ...
# ..                                                 ...
# 148  Laboratorios al aire libre y mucho dinero; así...
# 149  UVEG: Maestrías en Universidad Virtual del Est...
# 150  Decomisarán a comercios bolsas y contenedores ...
# 151  ¿Cuándo y dónde ver la ida de Octavos de Final...
# 152  En picada, ahorro en México este sexenio; peor...
#
#                                                    url
# 0    https://www.eluniversal.com.mx/opinion/salvado...
# 1    http://www.eluniversal.com.mx/cartera/economia...
# 2    http://www.eluniversal.com.mx/mundo/coronaviru...
# 3    http://www.eluniversal.com.mx/universal-deport...
# 4    http://www.eluniversal.com.mx/cartera/radio-di...
# ..                                                 ...
# 148  http://www.eluniversal.com.mx/nacion/laborator...
# 149  http://www.unionguanajuato.mx/articulo/2020/02...
# 150  https://sanluis.eluniversal.com.mx/metropoli/2...
# 151  http://www.eluniversal.com.mx/universal-deport...
# 152  http://www.eluniversal.com.mx/cartera/en-picad...
#
# [153 rows x 3 columns]

# %% [markdown]
# ## Index and selection

# %%
# dictionary like

el_universal['title']
# Out:
# 0         AMLO y Madero, entre la devoción y la obsesión
# 1      Inflación alcanza nivel más alto desde fines d...
# 2      China probablemente evitó cientos de miles de ...
# 3      Portero de León sería sancionado por protesta ...
# 4      Radio Disney regresa; por el 92.1 FM de Grupo ...
#                              ...
# 148    Laboratorios al aire libre y mucho dinero; así...
# 149    UVEG: Maestrías en Universidad Virtual del Est...
# 150    Decomisarán a comercios bolsas y contenedores ...
# 151    ¿Cuándo y dónde ver la ida de Octavos de Final...
# 152    En picada, ahorro en México este sexenio; peor...
# Name: title, Length: 153, dtype: object

# %%
el_universal[['title','url']]
# Out:
#                                                  title  \
# 0       AMLO y Madero, entre la devoción y la obsesión
# 1    Inflación alcanza nivel más alto desde fines d...
# 2    China probablemente evitó cientos de miles de ...
# 3    Portero de León sería sancionado por protesta ...
# 4    Radio Disney regresa; por el 92.1 FM de Grupo ...
# ..                                                 ...
# 148  Laboratorios al aire libre y mucho dinero; así...
# 149  UVEG: Maestrías en Universidad Virtual del Est...
# 150  Decomisarán a comercios bolsas y contenedores ...
# 151  ¿Cuándo y dónde ver la ida de Octavos de Final...
# 152  En picada, ahorro en México este sexenio; peor...
#
#                                                    url
# 0    https://www.eluniversal.com.mx/opinion/salvado...
# 1    http://www.eluniversal.com.mx/cartera/economia...
# 2    http://www.eluniversal.com.mx/mundo/coronaviru...
# 3    http://www.eluniversal.com.mx/universal-deport...
# 4    http://www.eluniversal.com.mx/cartera/radio-di...
# ..                                                 ...
# 148  http://www.eluniversal.com.mx/nacion/laborator...
# 149  http://www.unionguanajuato.mx/articulo/2020/02...
# 150  https://sanluis.eluniversal.com.mx/metropoli/2...
# 151  http://www.eluniversal.com.mx/universal-deport...
# 152  http://www.eluniversal.com.mx/cartera/en-picad...
#
# [153 rows x 2 columns]

# %%
# Numpy like

el_universal.iloc[10:15]
# Out:
#                                                  body  \
# 10  \r\n“Seas quien seas, sea cual sea tu posición...
# 11  \r\nDeben ser los DIF municipales los encargad...
# 12  \r\nNaucalpan, Méx.- El automovilista que volc...
# 13  \r\n\r\n\r\n\r\n    googletag.cmd.push(functio...
# 14  \r\nCuando se trata de juzgar a una mujer, el ...
#
#                                                 title  \
# 10                             Memorias de un piloto
# 11  Registro de adultos mayores en condición de ca...
# 12  Conductor de auto que "voló" en accidente en P...
# 13  Ricky Martin en Festiva Toluca 2020: Lo que de...
# 14  Mujeres en México reciben sentencias mayores q...
#
#                                                   url
# 10  https://www.eluniversalqueretaro.mx/portada/la...
# 11  https://sanluis.eluniversal.com.mx/sociedad/20...
# 12  http://www.eluniversal.com.mx/metropoli/cdmx/p...
# 13  http://www.unionedomex.mx/articulo/2020/02/24/...
# 14  http://www.eluniversal.com.mx/nacion/mujeres-e...

# %%
el_universal.iloc[66]['title']
# Out:
# '¿Qué es el Fakeminismo?'

# %%
el_universal.iloc[:5, 0]
# Out:
# 0    \r\nEnvuelto en las crisis de feminicidio, seg...
# 1    \r\nLa inflación nacional alcanzó el nivel más...
# 2    \r\nLas "decisiones increíblemente difíciles" ...
# 3    \r\nRodolfo Cota, portero de León, podría ser ...
# 4    \r\nEn unas semanas, Radio Disney regresa en l...
# Name: body, dtype: object

# %%
# Label Based
el_universal.loc[:, 'body': 'title']
# Out:
#                                                   body  \
# 0    \r\nEnvuelto en las crisis de feminicidio, seg...
# 1    \r\nLa inflación nacional alcanzó el nivel más...
# 2    \r\nLas "decisiones increíblemente difíciles" ...
# 3    \r\nRodolfo Cota, portero de León, podría ser ...
# 4    \r\nEn unas semanas, Radio Disney regresa en l...
# ..                                                 ...
# 148  \r\nSINALOA, MÉXICO. - Los laboratorios clande...
# 149  \r\n\r\n\r\n\r\n    googletag.cmd.push(functio...
# 150  \r\nConforme a los ajustes a la Ley Ambiental ...
# 151  \r\nEsta semana se reanuda la actividad de la ...
# 152  \r\n\r\nAnte la escasez de ingresos, la poblac...
#
#                                                  title
# 0       AMLO y Madero, entre la devoción y la obsesión
# 1    Inflación alcanza nivel más alto desde fines d...
# 2    China probablemente evitó cientos de miles de ...
# 3    Portero de León sería sancionado por protesta ...
# 4    Radio Disney regresa; por el 92.1 FM de Grupo ...
# ..                                                 ...
# 148  Laboratorios al aire libre y mucho dinero; así...
# 149  UVEG: Maestrías en Universidad Virtual del Est...
# 150  Decomisarán a comercios bolsas y contenedores ...
# 151  ¿Cuándo y dónde ver la ida de Octavos de Final...
# 152  En picada, ahorro en México este sexenio; peor...
#
# [153 rows x 2 columns]

# %% [markdown]
# ## Data wrangling

# %%
# 1. Añadir la columna newspaper_uid al DataFrame

el_universal['newspaper_uid'] = 'eluniversal'

el_universal
# Out:
#                                                   body  \
# 0    \r\nEnvuelto en las crisis de feminicidio, seg...
# 1    \r\nLa inflación nacional alcanzó el nivel más...
# 2    \r\nLas "decisiones increíblemente difíciles" ...
# 3    \r\nRodolfo Cota, portero de León, podría ser ...
# 4    \r\nEn unas semanas, Radio Disney regresa en l...
# ..                                                 ...
# 148  \r\nSINALOA, MÉXICO. - Los laboratorios clande...
# 149  \r\n\r\n\r\n\r\n    googletag.cmd.push(functio...
# 150  \r\nConforme a los ajustes a la Ley Ambiental ...
# 151  \r\nEsta semana se reanuda la actividad de la ...
# 152  \r\n\r\nAnte la escasez de ingresos, la poblac...
#
#                                                  title  \
# 0       AMLO y Madero, entre la devoción y la obsesión
# 1    Inflación alcanza nivel más alto desde fines d...
# 2    China probablemente evitó cientos de miles de ...
# 3    Portero de León sería sancionado por protesta ...
# 4    Radio Disney regresa; por el 92.1 FM de Grupo ...
# ..                                                 ...
# 148  Laboratorios al aire libre y mucho dinero; así...
# 149  UVEG: Maestrías en Universidad Virtual del Est...
# 150  Decomisarán a comercios bolsas y contenedores ...
# 151  ¿Cuándo y dónde ver la ida de Octavos de Final...
# 152  En picada, ahorro en México este sexenio; peor...
#
#                                                    url newspaper_uid
# 0    https://www.eluniversal.com.mx/opinion/salvado...   eluniversal
# 1    http://www.eluniversal.com.mx/cartera/economia...   eluniversal
# 2    http://www.eluniversal.com.mx/mundo/coronaviru...   eluniversal
# 3    http://www.eluniversal.com.mx/universal-deport...   eluniversal
# 4    http://www.eluniversal.com.mx/cartera/radio-di...   eluniversal
# ..                                                 ...           ...
# 148  http://www.eluniversal.com.mx/nacion/laborator...   eluniversal
# 149  http://www.unionguanajuato.mx/articulo/2020/02...   eluniversal
# 150  https://sanluis.eluniversal.com.mx/metropoli/2...   eluniversal
# 151  http://www.eluniversal.com.mx/universal-deport...   eluniversal
# 152  http://www.eluniversal.com.mx/cartera/en-picad...   eluniversal
#
# [153 rows x 4 columns]

# %%
# 2. Obtener el host
from urllib.parse import urlparse

el_universal['host'] = el_universal['url'].apply(lambda url: urlparse(url).netloc)

el_universal
# Out:
#                                                   body  \
# 0    \r\nEnvuelto en las crisis de feminicidio, seg...
# 1    \r\nLa inflación nacional alcanzó el nivel más...
# 2    \r\nLas "decisiones increíblemente difíciles" ...
# 3    \r\nRodolfo Cota, portero de León, podría ser ...
# 4    \r\nEn unas semanas, Radio Disney regresa en l...
# ..                                                 ...
# 148  \r\nSINALOA, MÉXICO. - Los laboratorios clande...
# 149  \r\n\r\n\r\n\r\n    googletag.cmd.push(functio...
# 150  \r\nConforme a los ajustes a la Ley Ambiental ...
# 151  \r\nEsta semana se reanuda la actividad de la ...
# 152  \r\n\r\nAnte la escasez de ingresos, la poblac...
#
#                                                  title  \
# 0       AMLO y Madero, entre la devoción y la obsesión
# 1    Inflación alcanza nivel más alto desde fines d...
# 2    China probablemente evitó cientos de miles de ...
# 3    Portero de León sería sancionado por protesta ...
# 4    Radio Disney regresa; por el 92.1 FM de Grupo ...
# ..                                                 ...
# 148  Laboratorios al aire libre y mucho dinero; así...
# 149  UVEG: Maestrías en Universidad Virtual del Est...
# 150  Decomisarán a comercios bolsas y contenedores ...
# 151  ¿Cuándo y dónde ver la ida de Octavos de Final...
# 152  En picada, ahorro en México este sexenio; peor...
#
#                                                    url newspaper_uid  \
# 0    https://www.eluniversal.com.mx/opinion/salvado...   eluniversal
# 1    http://www.eluniversal.com.mx/cartera/economia...   eluniversal
# 2    http://www.eluniversal.com.mx/mundo/coronaviru...   eluniversal
# 3    http://www.eluniversal.com.mx/universal-deport...   eluniversal
# 4    http://www.eluniversal.com.mx/cartera/radio-di...   eluniversal
# ..                                                 ...           ...
# 148  http://www.eluniversal.com.mx/nacion/laborator...   eluniversal
# 149  http://www.unionguanajuato.mx/articulo/2020/02...   eluniversal
# 150  https://sanluis.eluniversal.com.mx/metropoli/2...   eluniversal
# 151  http://www.eluniversal.com.mx/universal-deport...   eluniversal
# 152  http://www.eluniversal.com.mx/cartera/en-picad...   eluniversal
#
#                            host
# 0        www.eluniversal.com.mx
# 1        www.eluniversal.com.mx
# 2        www.eluniversal.com.mx
# 3        www.eluniversal.com.mx
# 4        www.eluniversal.com.mx
# ..                          ...
# 148      www.eluniversal.com.mx
# 149      www.unionguanajuato.mx
# 150  sanluis.eluniversal.com.mx
# 151      www.eluniversal.com.mx
# 152      www.eluniversal.com.mx
#
# [153 rows x 5 columns]

# %%
el_universal['host'].value_counts()
# Out:
# www.eluniversal.com.mx       102
# www.viveusa.mx                11
# de10.com.mx                    7
# www.elgrafico.mx               5
# oaxaca.eluniversal.com.mx      5
#                             ...
# www.unionjalisco.mx            2
# www.unionyucatan.mx            2
# www.unionedomex.mx             2
# www.unionguanajuato.mx         2
# www.clubeluniversal.mx         1
# Name: host, Length: 14, dtype: int64

# %% [markdown]
# ## Missing Data

# %%
# 3. Rellenar datos faltantes 
missing_title_mask = el_universal['title'].isna()

missing_titles = (el_universal[missing_title_mask]['url']
                      .str.extract(r'(?P<missing_titles>[^/]+)$')
                      .applymap(lambda title: title.split('-'))
                      .applymap(lambda title_word_list:' '.join(title_word_list)))
missing_titles
# Out:
#                                         missing_titles
# 6    costo de los vestidos de novia inspirados en p...
# 7    trump veta inmigrantes que puedan ser una carg...
# 18   10 anecdotas muy locas para celebrar el dia de...
# 30   que hacer si pierdes la visa pasaporte green c...
# 34   10 peliculas prohibidas por escenas violentas ...
# ..                                                 ...
# 135  sarah kohan impacta en instagram con bikini bl...
# 137                los 10 mejores libros del siglo xxi
# 143  novia de microbusero inventa robo de celular y...
# 145  requisitos para obtener la visa dorada de inve...
# 147  atoran joven que decapito aguila del hemiciclo...
#
# [24 rows x 1 columns]

# %%
el_universal.loc[missing_title_mask,'title'] = missing_titles.loc[:, 'missing_titles']

# %% [markdown]
# ## Aditional Clean Up

# %%
# 4. Añadir uid a las filas
import hashlib

uids = (el_universal
           .apply(lambda row: hashlib.md5(bytes(row['url'].encode())), axis =1)
           .apply(lambda hash_object: hash_object.hexdigest())
        )
el_universal['uid'] = uids
el_universal.set_index('uid',inplace=True)
el_universal
# Out:
#                                                                                body  \
# uid
# 5e9bf032db1bb117faadc616845a6e37  \r\nEnvuelto en las crisis de feminicidio, seg...
# 679668d319632b146d3990d2a56517bb  \r\nLa inflación nacional alcanzó el nivel más...
# ed7fed0c42b863c1d2f39e19dd61e39c  \r\nLas "decisiones increíblemente difíciles" ...
# 26e3cc6f28f1f333b580a61ea0a8f369  \r\nRodolfo Cota, portero de León, podría ser ...
# f6a5ee382600093ee2bbed70863ca06d  \r\nEn unas semanas, Radio Disney regresa en l...
# ...                                                                             ...
# 396e06fb3e7233b7ca4ac77e21022f97  \r\nSINALOA, MÉXICO. - Los laboratorios clande...
# 75dcf8e6a9ec55f3a94b836aa0ee8e45  \r\n\r\n\r\n\r\n    googletag.cmd.push(functio...
# defcc600e128ddb86a870eee5cec5275  \r\nConforme a los ajustes a la Ley Ambiental ...
# 5de09c4829cfaee50eefdde4ba444b7a  \r\nEsta semana se reanuda la actividad de la ...
# 9fe0bb9e44168d827b1028b004cc8dca  \r\n\r\nAnte la escasez de ingresos, la poblac...
#
#                                                                               title  \
# uid
# 5e9bf032db1bb117faadc616845a6e37     AMLO y Madero, entre la devoción y la obsesión
# 679668d319632b146d3990d2a56517bb  Inflación alcanza nivel más alto desde fines d...
# ed7fed0c42b863c1d2f39e19dd61e39c  China probablemente evitó cientos de miles de ...
# 26e3cc6f28f1f333b580a61ea0a8f369  Portero de León sería sancionado por protesta ...
# f6a5ee382600093ee2bbed70863ca06d  Radio Disney regresa; por el 92.1 FM de Grupo ...
# ...                                                                             ...
# 396e06fb3e7233b7ca4ac77e21022f97  Laboratorios al aire libre y mucho dinero; así...
# 75dcf8e6a9ec55f3a94b836aa0ee8e45  UVEG: Maestrías en Universidad Virtual del Est...
# defcc600e128ddb86a870eee5cec5275  Decomisarán a comercios bolsas y contenedores ...
# 5de09c4829cfaee50eefdde4ba444b7a  ¿Cuándo y dónde ver la ida de Octavos de Final...
# 9fe0bb9e44168d827b1028b004cc8dca  En picada, ahorro en México este sexenio; peor...
#
#                                                                                 url
# uid
# 5e9bf032db1bb117faadc616845a6e37  https://www.eluniversal.com.mx/opinion/salvado...
# 679668d319632b146d3990d2a56517bb  http://www.eluniversal.com.mx/cartera/economia...
# ed7fed0c42b863c1d2f39e19dd61e39c  http://www.eluniversal.com.mx/mundo/coronaviru...
# 26e3cc6f28f1f333b580a61ea0a8f369  http://www.eluniversal.com.mx/universal-deport...
# f6a5ee382600093ee2bbed70863ca06d  http://www.eluniversal.com.mx/cartera/radio-di...
# ...                                                                             ...
# 396e06fb3e7233b7ca4ac77e21022f97  http://www.eluniversal.com.mx/nacion/laborator...
# 75dcf8e6a9ec55f3a94b836aa0ee8e45  http://www.unionguanajuato.mx/articulo/2020/02...
# defcc600e128ddb86a870eee5cec5275  https://sanluis.eluniversal.com.mx/metropoli/2...
# 5de09c4829cfaee50eefdde4ba444b7a  http://www.eluniversal.com.mx/universal-deport...
# 9fe0bb9e44168d827b1028b004cc8dca  http://www.eluniversal.com.mx/cartera/en-picad...
#
# [153 rows x 3 columns]

# %%
# 6. Limpieza a la columna body
stripped_body = (el_universal
                    .apply(lambda row: row['body'], axis=1)
                    .apply(lambda body: list(body))
                    .apply(lambda letters: list(map(lambda letter: letter.replace('\n', ''), letters)))
                    .apply(lambda letters: list(map(lambda letter: letter.replace('\r', ''), letters)))
                    .apply(lambda letters: ''.join(letters)) 
                )
stripped_body
# Out:
# 0      Envuelto en las crisis de feminicidio, segurid...
# 1      La inflación nacional alcanzó el nivel más alt...
# 2      Las "decisiones increíblemente difíciles" que ...
# 3      Rodolfo Cota, portero de León, podría ser susp...
# 4      En unas semanas, Radio Disney regresa en la fr...
#                              ...
# 148    SINALOA, MÉXICO. - Los laboratorios clandestin...
# 149        googletag.cmd.push(function() {      googl...
# 150    Conforme a los ajustes a la Ley Ambiental del ...
# 151    Esta semana se reanuda la actividad de la UEFA...
# 152    Ante la escasez de ingresos, la población mexi...
# Length: 153, dtype: object

# %% [markdown]
# ## Data enrichment

# %%
# 6. Tokenizar el titulo y el body
import nltk
from nltk.corpus import stopwords

# nltk.download(´punkt')
# nltk.download('stopwords')

stop_words = set(stopwords.words('spanish'))

def tokenize_column(df, column_name):
    return (df
                .dropna()
                .apply(lambda row: nltk.word_tokenize(row[column_name]), axis = 1)
                .apply(lambda tokens: list(filter(lambda token: token.isalpha(), tokens)))
                .apply(lambda tokens: list(map(lambda token: token.lower(), tokens)))
                .apply(lambda word_list: list(filter(lambda word: word not in stop_words, word_list)))
                .apply(lambda valid_word_list: len(valid_word_list))
            )

el_universal['n_tokens_title'] = tokenize_column(el_universal, 'title')
el_universal['n_tokens_body'] = tokenize_column(el_universal, 'body')
el_universal
# Out:
#                                                   body  \
# 0    \r\nEnvuelto en las crisis de feminicidio, seg...
# 1    \r\nLa inflación nacional alcanzó el nivel más...
# 2    \r\nLas "decisiones increíblemente difíciles" ...
# 3    \r\nRodolfo Cota, portero de León, podría ser ...
# 4    \r\nEn unas semanas, Radio Disney regresa en l...
# ..                                                 ...
# 148  \r\nSINALOA, MÉXICO. - Los laboratorios clande...
# 149  \r\n\r\n\r\n\r\n    googletag.cmd.push(functio...
# 150  \r\nConforme a los ajustes a la Ley Ambiental ...
# 151  \r\nEsta semana se reanuda la actividad de la ...
# 152  \r\n\r\nAnte la escasez de ingresos, la poblac...
#
#                                                  title  \
# 0       AMLO y Madero, entre la devoción y la obsesión
# 1    Inflación alcanza nivel más alto desde fines d...
# 2    China probablemente evitó cientos de miles de ...
# 3    Portero de León sería sancionado por protesta ...
# 4    Radio Disney regresa; por el 92.1 FM de Grupo ...
# ..                                                 ...
# 148  Laboratorios al aire libre y mucho dinero; así...
# 149  UVEG: Maestrías en Universidad Virtual del Est...
# 150  Decomisarán a comercios bolsas y contenedores ...
# 151  ¿Cuándo y dónde ver la ida de Octavos de Final...
# 152  En picada, ahorro en México este sexenio; peor...
#
#                                                    url  n_tokens_title  \
# 0    https://www.eluniversal.com.mx/opinion/salvado...             4.0
# 1    http://www.eluniversal.com.mx/cartera/economia...             6.0
# 2    http://www.eluniversal.com.mx/mundo/coronaviru...             8.0
# 3    http://www.eluniversal.com.mx/universal-deport...             5.0
# 4    http://www.eluniversal.com.mx/cartera/radio-di...             6.0
# ..                                                 ...             ...
# 148  http://www.eluniversal.com.mx/nacion/laborator...             8.0
# 149  http://www.unionguanajuato.mx/articulo/2020/02...             5.0
# 150  https://sanluis.eluniversal.com.mx/metropoli/2...             7.0
# 151  http://www.eluniversal.com.mx/universal-deport...             7.0
# 152  http://www.eluniversal.com.mx/cartera/en-picad...             6.0
#
#      n_tokens_body
# 0            496.0
# 1             60.0
# 2            190.0
# 3            123.0
# 4             86.0
# ..             ...
# 148          839.0
# 149          136.0
# 150          124.0
# 151           64.0
# 152          441.0
#
# [153 rows x 5 columns]

# %% [markdown]
# ## Duplicate values

# %%
# 8. Eliminar duplicados
el_universal['title'].value_counts()
# Out:
# Katherine Johnson, la matemática que llevó a la humanidad a la Luna                      1
# Jurado halla a Harvey Weinstein culpable de dos delitos sexuales; absuelve los graves    1
# UVEG: Maestrías en Universidad Virtual del Estado de Guanajuato                          1
# El movimiento feminista es de izquierda                                                  1
# De Canadá a EU Migrantes usan “la otra frontera”                                         1
#                                                                                         ..
# Gobernadores se unen a paro nacional #UnDíaSinMujeres                                    1
# Gerente intenta frustrar asalto y lo matan en Sanborns de la Del Valle                   1
# Familiar de Yunes se alía con la 4T                                                      1
# De Harvey Weinstein a Ed Razek: modelos de Victoria's Secret denuncian acoso             1
# Cuando los temblores se medían en padrenuestros y avemarías                              1
# Name: title, Length: 129, dtype: int64

# %%
el_universal.drop_duplicates(subset=['title'], keep = 'first', inplace=True)

# %%
#Tabla final
el_universal
# Out:
#                                                                                body  \
# uid
# 5e9bf032db1bb117faadc616845a6e37  \r\nEnvuelto en las crisis de feminicidio, seg...
# 679668d319632b146d3990d2a56517bb  \r\nLa inflación nacional alcanzó el nivel más...
# ed7fed0c42b863c1d2f39e19dd61e39c  \r\nLas "decisiones increíblemente difíciles" ...
# 26e3cc6f28f1f333b580a61ea0a8f369  \r\nRodolfo Cota, portero de León, podría ser ...
# f6a5ee382600093ee2bbed70863ca06d  \r\nEn unas semanas, Radio Disney regresa en l...
# ...                                                                             ...
# 396e06fb3e7233b7ca4ac77e21022f97  \r\nSINALOA, MÉXICO. - Los laboratorios clande...
# 75dcf8e6a9ec55f3a94b836aa0ee8e45  \r\n\r\n\r\n\r\n    googletag.cmd.push(functio...
# defcc600e128ddb86a870eee5cec5275  \r\nConforme a los ajustes a la Ley Ambiental ...
# 5de09c4829cfaee50eefdde4ba444b7a  \r\nEsta semana se reanuda la actividad de la ...
# 9fe0bb9e44168d827b1028b004cc8dca  \r\n\r\nAnte la escasez de ingresos, la poblac...
#
#                                                                               title  \
# uid
# 5e9bf032db1bb117faadc616845a6e37     AMLO y Madero, entre la devoción y la obsesión
# 679668d319632b146d3990d2a56517bb  Inflación alcanza nivel más alto desde fines d...
# ed7fed0c42b863c1d2f39e19dd61e39c  China probablemente evitó cientos de miles de ...
# 26e3cc6f28f1f333b580a61ea0a8f369  Portero de León sería sancionado por protesta ...
# f6a5ee382600093ee2bbed70863ca06d  Radio Disney regresa; por el 92.1 FM de Grupo ...
# ...                                                                             ...
# 396e06fb3e7233b7ca4ac77e21022f97  Laboratorios al aire libre y mucho dinero; así...
# 75dcf8e6a9ec55f3a94b836aa0ee8e45  UVEG: Maestrías en Universidad Virtual del Est...
# defcc600e128ddb86a870eee5cec5275  Decomisarán a comercios bolsas y contenedores ...
# 5de09c4829cfaee50eefdde4ba444b7a  ¿Cuándo y dónde ver la ida de Octavos de Final...
# 9fe0bb9e44168d827b1028b004cc8dca  En picada, ahorro en México este sexenio; peor...
#
#                                                                                 url  \
# uid
# 5e9bf032db1bb117faadc616845a6e37  https://www.eluniversal.com.mx/opinion/salvado...
# 679668d319632b146d3990d2a56517bb  http://www.eluniversal.com.mx/cartera/economia...
# ed7fed0c42b863c1d2f39e19dd61e39c  http://www.eluniversal.com.mx/mundo/coronaviru...
# 26e3cc6f28f1f333b580a61ea0a8f369  http://www.eluniversal.com.mx/universal-deport...
# f6a5ee382600093ee2bbed70863ca06d  http://www.eluniversal.com.mx/cartera/radio-di...
# ...                                                                             ...
# 396e06fb3e7233b7ca4ac77e21022f97  http://www.eluniversal.com.mx/nacion/laborator...
# 75dcf8e6a9ec55f3a94b836aa0ee8e45  http://www.unionguanajuato.mx/articulo/2020/02...
# defcc600e128ddb86a870eee5cec5275  https://sanluis.eluniversal.com.mx/metropoli/2...
# 5de09c4829cfaee50eefdde4ba444b7a  http://www.eluniversal.com.mx/universal-deport...
# 9fe0bb9e44168d827b1028b004cc8dca  http://www.eluniversal.com.mx/cartera/en-picad...
#
#                                  newspaper_uid                        host  \
# uid
# 5e9bf032db1bb117faadc616845a6e37   eluniversal      www.eluniversal.com.mx
# 679668d319632b146d3990d2a56517bb   eluniversal      www.eluniversal.com.mx
# ed7fed0c42b863c1d2f39e19dd61e39c   eluniversal      www.eluniversal.com.mx
# 26e3cc6f28f1f333b580a61ea0a8f369   eluniversal      www.eluniversal.com.mx
# f6a5ee382600093ee2bbed70863ca06d   eluniversal      www.eluniversal.com.mx
# ...                                        ...                         ...
# 396e06fb3e7233b7ca4ac77e21022f97   eluniversal      www.eluniversal.com.mx
# 75dcf8e6a9ec55f3a94b836aa0ee8e45   eluniversal      www.unionguanajuato.mx
# defcc600e128ddb86a870eee5cec5275   eluniversal  sanluis.eluniversal.com.mx
# 5de09c4829cfaee50eefdde4ba444b7a   eluniversal      www.eluniversal.com.mx
# 9fe0bb9e44168d827b1028b004cc8dca   eluniversal      www.eluniversal.com.mx
#
#                                   n_tokens_title  n_tokens_body
# uid
# 5e9bf032db1bb117faadc616845a6e37             4.0          496.0
# 679668d319632b146d3990d2a56517bb             6.0           60.0
# ed7fed0c42b863c1d2f39e19dd61e39c             8.0          190.0
# 26e3cc6f28f1f333b580a61ea0a8f369             5.0          123.0
# f6a5ee382600093ee2bbed70863ca06d             6.0           86.0
# ...                                          ...            ...
# 396e06fb3e7233b7ca4ac77e21022f97             8.0          839.0
# 75dcf8e6a9ec55f3a94b836aa0ee8e45             5.0          136.0
# defcc600e128ddb86a870eee5cec5275             7.0          124.0
# 5de09c4829cfaee50eefdde4ba444b7a             7.0           64.0
# 9fe0bb9e44168d827b1028b004cc8dca             6.0          441.0
#
# [130 rows x 7 columns]

# %% [markdown]
# ## Descriptive Analysis

# %%
clean_eluniversal = pd.read_csv('C:\Python\web_scrapper\clean_eluniversal_2020_02_24_articles.csv',encoding='utf-8')
clean_spdnoticias = pd.read_csv('C:\Python\web_scrapper\clean_spdnoticias_2020_02_26_articles.csv',encoding='utf-8')

# %%
clean_eluniversal.describe()
# Out:
#        n_tokens_title  n_tokens_body
# count      153.000000     153.000000
# mean         5.869281     294.967320
# std          1.876772     245.032447
# min          1.000000       9.000000
# 25%          5.000000     126.000000
# 50%          6.000000     230.000000
# 75%          7.000000     363.000000
# max         10.000000    1765.000000

# %%
clean_spdnoticias.describe()
# Out:
#        n_tokens_title  n_tokens_body
# count       69.000000      69.000000
# mean         5.927536     266.333333
# std          2.283694     130.260674
# min          1.000000     113.000000
# 25%          5.000000     169.000000
# 50%          6.000000     218.000000
# 75%          7.000000     358.000000
# max         12.000000     619.000000

# %%
clean_eluniversal.loc[clean_eluniversal['n_tokens_title'] == 1]
# Out:
#                                  uid  \
# 66  f58846b072de5fabe58ab92d81e4880c
# 81  3e542ff3beadc7730bbe798190f3cf39
#
#                                                  body  \
# 66    El sábado, la secretaria de la Función Públi...
# 81   Toggle navigation  SuscripcionesEl Universal ...
#
#                       title  \
# 66  ¿Qué es el Fakeminismo?
# 81            suscripciones
#
#                                                   url newspaper_uid  \
# 66  http://www.eluniversal.com.mx/nacion/politica/...   eluniversal
# 81  https://www.clubeluniversal.mx/content/suscrip...   eluniversal
#
#                       host  n_tokens_title  n_tokens_body
# 66  www.eluniversal.com.mx               1            397
# 81  www.clubeluniversal.mx               1              9

# %%
# %matplotlib inline

# %%
clean_eluniversal['n_tokens_title'].plot(style='k.')
clean_spdnoticias['n_tokens_title'].plot(style='r.')

# %%
clean_eluniversal['n_tokens_body'].plot(style='k.')
clean_spdnoticias['n_tokens_body'].plot(style='r.')

# %%
all_newspapers = pd.concat([clean_eluniversal, clean_spdnoticias])
grouped = all_newspapers.groupby('newspaper_uid')
grouped.hist()
# Out:
# newspaper_uid
# eluniversal    [[AxesSubplot(0.125,0.125;0.336957x0.755), Axe...
# spdnoticias    [[AxesSubplot(0.125,0.125;0.336957x0.755), Axe...
# dtype: object

# %%
grouped['n_tokens_body'].agg(['min','mean','max'])
# Out:
#                min        mean   max
# newspaper_uid
# eluniversal      9  294.967320  1765
# spdnoticias    113  266.333333   619

# %%
grouped.plot()
# Out:
# newspaper_uid
# eluniversal    AxesSubplot(0.125,0.125;0.775x0.755)
# spdnoticias    AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object
