# %%
import requests

response = requests.get('https://www.eluniversal.com.mx/')

print(dir(response))
# Out:
# ['__attrs__', '__bool__', '__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__enter__', '__eq__', '__exit__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__nonzero__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__setstate__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_content', '_content_consumed', '_next', 'apparent_encoding', 'close', 'connection', 'content', 'cookies', 'elapsed', 'encoding', 'headers', 'history', 'is_permanent_redirect', 'is_redirect', 'iter_content', 'iter_lines', 'json', 'links', 'next', 'ok', 'raise_for_status', 'raw', 'reason', 'request', 'status_code', 'text', 'url']

# %%
print(response.text)
# Out:
# <!DOCTYPE HTML>
# <html lang="es" dir="ltr" xmlns="https://www.w3.org/1999/xhtml" prefix="og: https://ogp.me/ns# article: https://ogp.me/ns/article# book: https://ogp.me/ns/book# profile: https://ogp.me/ns/profile# video: https://ogp.me/ns/video#">
# <head>
# <script>
#   var nua = "nav"+"igator.u"+"serAgent";
#
#   if (window.location.pathname == '/'){
#     var isMobile = false; //initiate as false
#     if(/(android|bb\d+|meego).+mobile|avantgo|bada\/|blackberry|blazer|compal|elaine|fennec|hiptop|iemobile|ip(hone|od)|iris|kindle|Android|Silk|lge |maemo|midp|mmp|netfront|opera m(ob|in)i|palm( os)?|phone|p(ixi|re)\/|plucker|pocket|psp|series(4|6)0|symbian|treo|up\.(browser|link)|vodafone|wap|windows (ce|phone)|xda|xiino/i.test(eval(nua))
# ...

# %%
import bs4

soup = bs4.BeautifulSoup(response.text,'html.parser')

print(soup.title.text)
# Out:
# El Universal | El periódico de México líder en noticias y clasificados

# %%
import requests
import bs4
resp = requests.get('https://www.eluniversal.com.mx/')
soup = bs4.BeautifulSoup(resp.text, 'html.parser')
Linksarticulo = soup.select('.field-content h2 a')

links = [link['href'] for link in Linksarticulo]
print('ARTICULOS')
for link in links:
    print(link)
    print('************************************************************************************************************')
# Out:
# ARTICULOS
# /nacion/por-covid-19-se-han-perdido-346-mil-puestos-de-trabajo-stps
# ************************************************************************************************************
# /nacion/politica/coronavirus-confirma-imss-que-hay-20-medicos-contagiados-en-clinica-de-tlalne
# ************************************************************************************************************
# /cartera/covid-19-ocde-observa-las-peores-caidas-en-economias-en-desarrollo
# ************************************************************************************************************
# /mundo/bernie-sanders-deja-carrera-presidencial-durante-crisis-por-covid-19
# ************************************************************************************************************
# /cartera/carlos-slim-y-familia-salen-de-top-10-de-billonarios
# ************************************************************************************************************
# ...

# %%
import requests
import bs4

response = requests.get('https://www.eluniversal.com.mx/')
soup = bs4.BeautifulSoup(response.text, 'html.parser')

titlesH1 = soup.select('h1.field-content a')
titlesH2 = soup.select('h2.field-content a')

titles = [title.get_text() for title in titlesH1] + [title.get_text() for title in titlesH2]

print(len(titles))

for title in titles:
    print(title)
# Out:
# 70
# Reporta SRE 108 mexicanos fallecidos en EU por coronavirus
# Coronavirus en México
# Cuarentena
# Coronavirus
# Por Covid-19, se han perdido más de 346 mil puestos de trabajo: STPS
# Confirma IMSS que hay 20 médicos contagiados de Covid-19 en Tlalne
# OCDE observa las peores caídas en economías en desarrollo durante cuarentena por Covid-19
# Bernie Sanders deja carrera presidencial durante crisis por Covid-19
# Carlos Slim Helú y familia salen de top 10 de billonarios
# Líder empresarial Carlos Salazar Lomelín cumple con su papel de defender a su gremio: AMLO
# Entérate: ¿Qué hicieron Zedillo y Calderón frente a las crisis económicas?
# Genera indignación feminicidio de la niña Ana Paola durante cuarentena
# Profeco publica marcas que dicen ser queso manchego, pero no lo son
# "No politice el virus", responde director de la OMS a Trump
# Tres municipios de Veracruz prohíben entrada a foráneos por Covid-19
# ...

# %%
import requests
import bs4

response = requests.get('https://www.eluniversal.com.mx/')
soup = bs4.BeautifulSoup(response.text,'html.parser')

tittle_names = soup.select('.field-content a')
tittle_links = soup.select('.field-content a')

names = [name.get_text() for name in tittle_names]
links = [link['href'] for link in tittle_links]

print(soup.title.text)
print(' ')

for name in range(len(names)):
    print(names[name]+': '+'https://www.eluniversal.com.mx'+ links[name])

print(' ')
print(f'Numero de notas:{len(names)}')
# Out:
# El Universal | El periódico de México líder en noticias y clasificados
#
# Coronavirus en México: https://www.eluniversal.com.mx/es-noticia/nacion/sociedad/coronavirus-en-mexico
# Cuarentena: https://www.eluniversal.com.mx/es-noticia/nacion/sociedad/cuarentena
# Coronavirus: https://www.eluniversal.com.mx/es-noticia/mundo/coronavirus
# : https://www.eluniversal.com.mxhttps://www.eluniversal.com.mx/opinion/editorial-el-universal/ayuda-y-quedateencasa
# Coronavirus (COVID-19): https://www.eluniversal.com.mxhttps://www.eluniversal.com.mx/mundo/coronavirus-covid-19
#
#
#
#
# : https://www.eluniversal.com.mxhttps://www.eluniversal.com.mx/mundo/coronavirus-covid-19
# Historias: https://www.eluniversal.com.mxhttps://www.eluniversal.com.mx/mundo/coronavirus-covid-19
# English: https://www.eluniversal.com.mxhttps://www.eluniversal.com.mx/mundo/coronavirus-covid-19/notas/1#info
# Deportes: https://www.eluniversal.com.mxhttps://www.eluniversal.com.mx/mundo/coronavirus-covid-19/notas/2#info
# ...
